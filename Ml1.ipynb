# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\jupiter notebook\st.csv', sep=',')
df.tail(20)
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 166   21     161         36              3           2001             12
# 167   21     168         40              4           2001            100
# 168   22     161         38              7           2000             50
# 169   21     160         37              4           2001            221
# 170   22     168         38              4           2000             49
# 171   20     162         37              2           2002             70
# 172   21     164         37              4           2000            260
# 173   29     176         39              7           1992            233
# 174   20     158         37              3           2001             21
# 175   18     176         38              2           2003            183
# 176   21     162         38              7           2000            150
# 177   23     155         36              6           1999             90
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df.describe()
# Out:
#               Age      Growth   Shoe size  Course number  Year of birth  \
# count  186.000000  186.000000  186.000000     186.000000     186.000000
# mean    20.688172  170.661290   39.715054       3.500000    1991.107527
# std      3.468713    9.055881    2.814920       3.147285     132.099550
# min     17.000000  153.000000   34.000000       0.000000     200.000000
# 25%     19.000000  164.000000   38.000000       2.000000    2000.000000
# 50%     20.000000  169.000000   39.000000       3.000000    2001.500000
# 75%     21.000000  178.000000   42.000000       4.000000    2003.000000
# max     55.000000  197.000000   48.000000      37.000000    2004.000000
#
#        Friend number  Russian rating  Maths rating  Physics rating  \
# count     186.000000      186.000000    186.000000      186.000000
# mean      374.032258       81.634409     58.177419       13.182796
# std      2199.541507       14.325019     29.575478       26.414552
# ...

# %%
df['Growth'].mean()
# Out:
# 170.66129032258064

# %%
df.Growth.median()
# Out:
# 169.0

# %%
df_new = df[['Age','Growth','Weight']]

# %%
df_new
# Out:
#      Age  Growth  Weight
# 0     20     170    64.0
# 1     22     191    73.0
# 2     21     172    60.0
# 3     19     168    59.0
# 4     23     159    57.0
# ..   ...     ...     ...
# 181   23     168    59.0
# 182   19     169    43.0
# 183   18     161    51.0
# 184   19     169    62.0
# 185   18     164    54.0
#
# [186 rows x 3 columns]

# %%
df['Weight'].describe()
# Out:
# count    157.000000
# mean      64.031847
# std       16.502300
# min        3.000000
# 25%       53.000000
# 50%       60.000000
# 75%       71.000000
# max      120.000000
# Name: Weight, dtype: float64

# %%
df['Rock paper scissors'].value_counts()
# Out:
# Rock paper scissors
# Ножницы    88
# Камень     60
# Бумага     38
# Name: count, dtype: int64

# %%
df.iloc[9:10][["Sex",'Weight']]
# Out:
#        Sex  Weight
# 9  женский    58.0

# %%
df
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 0     20     170         40              2           2002            100
# 1     22     191         43              7           2000            307
# 2     21     172         41              4           2000            186
# 3     19     168         38              2           2003            604
# 4     23     159         36              1           1998            144
# ..   ...     ...        ...            ...            ...            ...
# 181   23     168         39              7           1999            228
# 182   19     169         38              1           2003              0
# 183   18     161         37              2           2003             11
# 184   19     169         41              1           2003             22
# 185   18     164         39              2           2003            500
#
#      Russian rating  Maths rating  Physics rating  Computer science rating  \
# ...

# %%
df[df['Growth']>df['Growth'].mean()]
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 1     22     191         43              7           2000            307
# 2     21     172         41              4           2000            186
# 5     18     177         40              2           2003            100
# 6     18     180         42              0           2004              0
# 7     19     180         48              1           2003              5
# ..   ...     ...        ...            ...            ...            ...
# 157   21     175         43              5           2000            400
# 160   19     180         41              1           2003            250
# 173   29     176         39              7           1992            233
# 175   18     176         38              2           2003            183
# 179   20     176         42              3           2001             80
#
#      Russian rating  Maths rating  Physics rating  Computer science rating  \
# ...

# %%
df['Growth'].mean()
# Out:
# 170.66129032258064

# %%
mw = df['Weight'].max()

# %%
mw = df['Weight'].max()
df[df['Weight'] == mw]['Growth']
# Out:
# 7    180
# Name: Growth, dtype: int64

# %%
army_persons = df[df['Army']=='могут призвать']
free_persons = df[df['Army']=='не призовут (по разным причинам)']
free_persons
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 0     20     170         40              2           2002            100
# 1     22     191         43              7           2000            307
# 3     19     168         38              2           2003            604
# 4     23     159         36              1           1998            144
# 6     18     180         42              0           2004              0
# ..   ...     ...        ...            ...            ...            ...
# 181   23     168         39              7           1999            228
# 182   19     169         38              1           2003              0
# 183   18     161         37              2           2003             11
# 184   19     169         41              1           2003             22
# 185   18     164         39              2           2003            500
#
#      Russian rating  Maths rating  Physics rating  Computer science rating  \
# ...

# %%
free_persons['Hair length'].mean()
# Out:
# 40.15570469798658

# %%
army_persons['Hair length'].mean()
# Out:
# 11.045945945945945

# %%
f = df[['Friend number','Sex']]
f[f['Friend number']==0]
# Out:
#      Friend number      Sex
# 6                0  мужской
# 182              0  женский

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
dog_love = df[df['Animal']=='Собак']
dog_love['Animal'].value_counts()
# Out:
# Animal
# Собак    60
# Name: count, dtype: int64

# %%
df2 = dog_love[dog_love['Floor number'] ==1]
df2['Floor number']
# Out:
# 6      1
# 26     1
# 61     1
# 72     1
# 128    1
# 153    1
# 183    1
# Name: Floor number, dtype: int64

# %%
df2['Floor number'].value_counts()
# Out:
# Floor number
# 1    7
# Name: count, dtype: int64

# %%
7/60*100
# Out:
# 11.666666666666666

# %%
df_cut = df[['Age','Growth','Weight']]
df_cut.head()
# Out:
#    Age  Growth  Weight
# 0   20     170    64.0
# 1   22     191    73.0
# 2   21     172    60.0
# 3   19     168    59.0
# 4   23     159    57.0

# %%
df_cut.sort_values(by=['Age','Growth'], ascending = [False,True])
# Out:
#      Age  Growth  Weight
# 81    55     160     3.0
# 63    35     180    78.0
# 99    31     165    53.0
# 173   29     176    70.0
# 82    27     168    58.0
# ..   ...     ...     ...
# 112   18     183    65.0
# 16    18     185    64.0
# 42    18     185    68.0
# 126   17     168    71.0
# 115   17     175    72.0
#
# [186 rows x 3 columns]

# %%
df_sorted = df_cut.sort_values(by='Growth', ascending = False)
df_sorted.iloc[2,2]
# Out:
# 73.0

# %%
df_cut['Mass Index'] = 10**4*df_cut['Weight']/(df_cut['Growth']**2)
# Out:
# C:\Temp\ipykernel_10924\3534804649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['Mass Index'] = 10**4*df_cut['Weight']/(df_cut['Growth']**2)

# %%
df_cut
# Out:
#      Age  Growth  Weight  Mass Index
# 0     20     170    64.0   22.145329
# 1     22     191    73.0   20.010416
# 2     21     172    60.0   20.281233
# 3     19     168    59.0   20.904195
# 4     23     159    57.0   22.546576
# ..   ...     ...     ...         ...
# 181   23     168    59.0   20.904195
# 182   19     169    43.0   15.055495
# 183   18     161    51.0   19.675167
# 184   19     169    62.0   21.707923
# 185   18     164    54.0   20.077335
#
# [186 rows x 4 columns]

# %%
df_cut.sort_values(by='Mass Index', ascending=True)
# Out:
#      Age  Growth  Weight  Mass Index
# 81    55     160     3.0    1.171875
# 114   22     178     7.0    2.209317
# 182   19     169    43.0   15.055495
# 5     18     177    50.0   15.959654
# 139   20     170    47.0   16.262976
# ..   ...     ...     ...         ...
# 158   21     168     NaN         NaN
# 161   24     163     NaN         NaN
# 167   21     168     NaN         NaN
# 170   22     168     NaN         NaN
# 178   21     170     NaN         NaN
#
# [186 rows x 4 columns]

# %%
df_cut.corr()
# Out:
#                  Age    Growth    Weight  Mass Index
# Age         1.000000 -0.101982 -0.185722   -0.200305
# Growth     -0.101982  1.000000  0.544528    0.146201
# Weight     -0.185722  0.544528  1.000000    0.904678
# Mass Index -0.200305  0.146201  0.904678    1.000000

# %%
df.groupby('Sex')[['Growth','Weight']].mean()
# Out:
#              Growth     Weight
# Sex
# женский  165.725000  59.105263
# мужской  179.636364  71.580645

# %%
df.groupby(['Sex','Chocolate'])[['Russian rating','Maths rating']].mean()
# Out:
#                                            Russian rating  Maths rating
# Sex     Chocolate
# женский M&Ms                                    79.400000     51.600000
#         Баунти                                  81.181818     56.318182
#         КитКат                                  85.782609     61.782609
#         Марс                                    91.166667     36.666667
#         Милки Вей                               79.583333     45.250000
#         Натс                                    84.636364     53.818182
#         Скиттлс (хотя это и не шоколадка)       86.000000     67.000000
#         Сникерс                                 80.375000     61.562500
#         Твикс                                   86.478261     55.217391
# мужской M&Ms                                    83.666667     76.666667
#         Баунти                                  78.375000     68.000000
#         КитКат                                  74.416667     51.083333
# ...

# %%
df.groupby('Chocolate')[['Russian rating','Maths rating']].mean()
# Out:
#                                    Russian rating  Maths rating
# Chocolate
# M&Ms                                    81.000000     61.000000
# Баунти                                  80.433333     59.433333
# КитКат                                  81.885714     58.114286
# Марс                                    88.636364     45.181818
# Милки Вей                               77.588235     50.117647
# Натс                                    82.461538     56.615385
# Скиттлс (хотя это и не шоколадка)       85.000000     72.000000
# Сникерс                                 78.941176     60.235294
# Твикс                                   84.323529     61.617647

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df_cut = df[['Year of birth','Growth','Weight','Hair length','Shoe size']]
df_cut
# Out:
#      Year of birth  Growth  Weight  Hair length  Shoe size
# 0             2002     170    64.0         50.0         40
# 1             2000     191    73.0          7.0         43
# 2             2000     172    60.0          4.0         41
# 3             2003     168    59.0         20.0         38
# 4             1998     159    57.0         55.0         36
# ..             ...     ...     ...          ...        ...
# 181           1999     168    59.0         30.0         39
# 182           2003     169    43.0         45.0         38
# 183           2003     161    51.0         40.0         37
# 184           2003     169    62.0        150.0         41
# 185           2003     164    54.0         60.0         39
#
# [186 rows x 5 columns]

# %%
df_cut.sort_values('Shoe size')
df_cut.sort_values(by=['Shoe size','Growth'], ascending=[False,True]).head(10)
# Out:
#      Year of birth  Growth  Weight  Hair length  Shoe size
# 7             2003     180   120.0         20.0         48
# 27            2003     193    61.0          3.0         48
# 8             2002     185    69.0         25.0         46
# 103           2002     197   100.0         23.0         46
# 55            1999     180    92.0          0.2         45
# 76            2002     184     NaN         20.0         45
# 145           1999     184    92.0         45.0         45
# 16            2003     185    64.0          4.0         45
# 20            2001     186    93.0         20.0         45
# 24            2002     177    65.0         12.0         44

# %%
df_cut['Full length'] = df_cut['Growth'] + df_cut['Hair length']
# Out:
# C:\Temp\ipykernel_10924\542438141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['Full length'] = df_cut['Growth'] + df_cut['Hair length']

# %%
df_cut.describe()
# Out:
#        Year of birth      Growth      Weight  Hair length   Shoe size  \
# count     186.000000  186.000000  157.000000   186.000000  186.000000
# mean     1991.107527  170.661290   64.031847    34.365054   39.715054
# std       132.099550    9.055881   16.502300    25.672211    2.814920
# min       200.000000  153.000000    3.000000     0.200000   34.000000
# 25%      2000.000000  164.000000   53.000000    12.000000   38.000000
# 50%      2001.500000  169.000000   60.000000    30.000000   39.000000
# 75%      2003.000000  178.000000   71.000000    50.000000   42.000000
# max      2004.000000  197.000000  120.000000   150.000000   48.000000
#
#        Full length
# count   186.000000
# mean    205.026344
# std      21.983827
# min     170.000000
# 25%     187.250000
# 50%     201.000000
# 75%     217.750000
# max     319.000000

# %%
df_cut.corr()
# Out:
#                Year of birth    Growth    Weight  Hair length  Shoe size  \
# Year of birth       1.000000 -0.113357  0.006042     0.095402  -0.108360
# Growth             -0.113357  1.000000  0.544528    -0.554408   0.863252
# Weight              0.006042  0.544528  1.000000    -0.319416   0.591149
# Hair length         0.095402 -0.554408 -0.319416     1.000000  -0.567568
# Shoe size          -0.108360  0.863252  0.591149    -0.567568   1.000000
# Full length         0.064713 -0.235492 -0.145316     0.939398  -0.307190
#
#                Full length
# Year of birth     0.064713
# Growth           -0.235492
# Weight           -0.145316
# Hair length       0.939398
# Shoe size        -0.307190
# Full length       1.000000

# %%
df_glass = df.groupby('Glasses')[['Russian rating','Maths rating']].mean()
df_glass
# Out:
#                                      Russian rating  Maths rating
# Glasses
# да                                        83.388235     56.741176
# нет                                       80.471910     59.955056
# простите. не увидел(а) вопроса ))))       77.900000     54.700000

# %%
df_game = df.groupby('Rock paper scissors')[['Russian rating','Maths rating']].mean()
df_game
# Out:
#                      Russian rating  Maths rating
# Rock paper scissors
# Бумага                    76.473684     52.894737
# Камень                    81.450000     62.166667
# Ножницы                   83.988636     57.738636
